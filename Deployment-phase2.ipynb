# %%
# phase-2
# deployment
import pickle
linear_model=pickle.load(open("finalized_simple_linear_regression.sav","rb"))
result=linear_model.predict([[10]])
result
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[120380.00420313]])
